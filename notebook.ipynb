# %% [markdown]
# # Buildables Fellowship
#
# ## Aqsa Majeed
#
# ### Data Analyst Track
#
# ### Task No. 02
#
# #### Githup Repo: https://github.com/aqsamajjeed/Ames-Housing-Analysis
#
# #### Medium Blog: https://medium.com/@aqsamajeed094/how-i-learned-data-analysis-with-python-in-7-days-752570b767da

# %% [markdown]
# ## Exercise 1:  Load dataset and show first 10 rows

# %% [markdown]
# **Purpose:**
#
# To confirm that the dataset loads correctly and to preview the structure of the data (columns, datatypes, and first records).
#
# **Concepts Used:**
#
# *pandas* for data loading and previewing
#
# *head()* to display the first few rows

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("C:\\Users\\Fame\\Documents\\DATA  ANALYSIS\\Buildables\\Task2_Python\\AmesHousing.csv")

# Show first 10 rows
df.head(10)
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
# 5      6  527105030           60        RL          78.0      9978   Pave
# 6      7  527127150          120        RL          41.0      4920   Pave
# 7      8  527145080          120        RL          43.0      5005   Pave
# 8      9  527146030          120        RL          39.0      5389   Pave
# 9     10  527162130           60        RL          60.0      7500   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# ...

# %% [markdown]
# **Expected Output:**
#
# A table showing the first 10 rows of the dataset.
#
# Should include columns like Order, PID, MS SubClass, MS Zoning, Lot Frontage, Lot Area, …, SalePrice.
#
# **Business Insight:**
#
# This step validates that the dataset is read correctly and gives an initial idea of what information is available (property attributes, neighborhood details, and sale prices). It’s the foundation for further analysis.

# %% [markdown]
# ## Exercise 2: Show dataset shape, columns, and dtypes

# %% [markdown]
# **Purpose:**
#
# To understand the structure of the dataset by checking its size, available columns, and data types. This gives us an overview of what kind of information we are working with.
#
# **Concepts Used:**
#
# - Pandas shape
#
# - Pandas columns
#
# - Pandas dtypes

# %%
# Dataset shape
print("Shape:", df.shape)

# Columns
print("\nColumns:\n", df.columns.tolist())

# Data types
print("\nData Types:\n", df.dtypes)
# Out:
# Shape: (2930, 82)
#
# Columns:
# ...

# %% [markdown]
# **Expected Output:**
#
# - Shape: (number_of_rows, number_of_columns)
#
# - List of all column names (as strings)
#
# - Data types for each column (int, float, object, etc.)
#
# **Business Insight:**
#
# The dataset is fairly large with 2,930 rows and 82 features, giving us a rich mix of property characteristics, neighborhood details, and final sale outcomes.
#
# Data types show a blend of:
#
# - Numeric columns (e.g., Lot Area, Gr Liv Area, SalePrice) for quantitative analysis.
#
# - Categorical columns (e.g., MS Zoning, Neighborhood, Sale Type) for segmentation and grouping.
#
# - Date-related fields (Year Built, Yr Sold, Mo Sold) that can support time-series analysis.
#
# - Some numeric fields are stored as float64 (e.g., Lot Frontage), indicating possible missing values.
#
# - This mix of categorical and numeric features makes the dataset ideal for both descriptive analytics and predictive modeling in real estate.

# %% [markdown]
# ## Exercise 3: Filter rows — Real Estate → Properties priced above $500,000

# %% [markdown]
# **Purpose:**
# Identify high-value properties in the dataset. This helps in targeting premium buyers or investors.
#
# **Concepts Used:**
# - Pandas filtering with conditions
# - Boolean indexing

# %%
# Filter properties with SalePrice above $500,000
high_value_properties = df[df["SalePrice"] > 500000]

# Show first 10 rows of filtered dataset
high_value_properties.head(10)
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 15       16  527216070           60        RL          47.0     53504   Pave
# 44       45  528150070           20        RL         100.0     12919   Pave
# 366     367  527214050           20        RL          63.0     17423   Pave
# 423     424  528106020           20        RL         105.0     15431   Pave
# 432     433  528110020           20        RL         105.0     13693   Pave
# 433     434  528110090           60        RL         107.0     13891   Pave
# 456     457  528176030           20        RL         100.0     14836   Pave
# 1063   1064  528164060           20        RL         106.0     12720   Pave
# 1637   1638  527216080           20        RL          52.0     51974   Pave
# 1701   1702  528118050           20        RL          59.0     17169   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC Fence Misc Feature  \
# ...

# %% [markdown]
# **Expected Output:**
#
# A DataFrame showing only properties where SalePrice > 500000.
# Columns like Order, PID, MS SubClass, Neighborhood, Gr Liv Area, Garage Area, SalePrice, etc.
# Only the first 10 rows are displayed for preview.
#
# **Business Insight:**
#
# - Shows the premium properties in the market.
#
# - Helps stakeholders analyze which neighborhoods, house types, or features correlate with high sale prices.
#
# - Useful for real estate investment decisions or marketing strategies targeting high-value buyers.

# %% [markdown]
# ## Exercise 4: Sort houses by SalePrice (highest first)

# %% [markdown]
# **Purpose:**
#
# To rank properties from the most expensive to the least expensive. This helps identify top-tier houses and spot trends in premium real estate.
#
# **Concepts Used:**
#
# - Pandas sort_values()
#
# - Descending order sorting (ascending=False)

# %%
# Sort houses by SalePrice in descending order
sorted_properties = df.sort_values(by="SalePrice", ascending=False)

# Show first 10 rows (highest priced properties)
sorted_properties.head(10)
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1767   1768  528351010           60        RL         104.0     21535   Pave
# 1760   1761  528320050           60        RL         160.0     15623   Pave
# 2445   2446  528320060           60        RL         118.0     35760   Pave
# 1063   1064  528164060           20        RL         106.0     12720   Pave
# 44       45  528150070           20        RL         100.0     12919   Pave
# 432     433  528110020           20        RL         105.0     13693   Pave
# 1637   1638  527216080           20        RL          52.0     51974   Pave
# 2450   2451  528360050           60        RL         114.0     17242   Pave
# 433     434  528110090           60        RL         107.0     13891   Pave
# 2332   2333  527212030           60        RL          85.0     16056   Pave
#
#      Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# ...

# %% [markdown]
# **Expected Output:**
#
# A DataFrame sorted by SalePrice in descending order.
#
# The top rows will show the most expensive houses first, including columns like Neighborhood, Gr Liv Area, Garage Area, and SalePrice.
#
# **Business Insight:**
#
# High-value homes (>$550k) in the dataset typically have large lot sizes, are located in residential low-density zones, and often include premium features like pools or modern upgrades. Most of these sales occurred between 2006–2009, suggesting strong market conditions then.
#
# **Use Case:**
#
#  Developers and agents should focus on large-lot, amenity-rich properties when targeting the luxury housing market.

# %% [markdown]
# ## Exercise 5: Check missing values per column

# %% [markdown]
# **Purpose:**
#
# To identify columns with missing or null data. This is critical for data cleaning and ensures accurate analysis.
#
# **Concepts Used:**
#
# - Pandas isnull() or isna()
#
# - sum() to count missing values per column

# %%
# Count missing values per column
missing_values = df.isnull().sum()

# Display columns with missing values only
missing_values[missing_values > 0]
# Out:
# Lot Frontage       490
# Alley             2732
# Mas Vnr Type      1775
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2917
# Fence             2358
# Misc Feature      2824
# dtype: int64

# %% [markdown]
# **Expected Output:**
#
# A series showing only columns that have missing values and the count of missing entries for each.
#
# **Business Insight:**
#
# Several property features have very high missing values, such as Pool QC, Misc Feature, Alley, and Fence. This suggests that these attributes are rare in the housing market (e.g., few houses have pools, alleys, or special features). On the other hand, critical attributes like lot size, basement area, and garage details have very few missing values, meaning they are consistently available and reliable for analysis.

# %% [markdown]
# ## Exercise 6: Fill missing values

# %% [markdown]
# **Purpose:**
#
# To handle missing data and ensure numeric columns can be used in analysis without errors. Filling missing values prevents calculation issues and maintains dataset integrity.
#
# **Concepts Used:**
#
# Pandas fillna()
#
# Using median to impute numeric missing values

# %%
# Fill missing 'Lot Frontage' values with median
df["Lot Frontage"].fillna(df["Lot Frontage"].median(), inplace=True)

# Verify missing values are filled
df["Lot Frontage"].isnull().sum()
# Out:
# C:\Users\Fame\AppData\Local\Temp\ipykernel_12392\191652297.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Lot Frontage"].fillna(df["Lot Frontage"].median(), inplace=True)
# np.int64(0)

# %% [markdown]
# **Expected Output**
#
# 0 → meaning no missing values remain in Lot Frontage column.
#
# Column now contains median values in place of previously missing entries.
#
# **Business Insight**
#
# Filling missing property size data ensures that analyses like correlations with SalePrice or size-based filtering will be accurate.
#
# Using median is robust against extreme outliers, maintaining realistic values for property size.

# %% [markdown]
# ## Exercise 7: Remove duplicates (property listings)

# %% [markdown]
# **Purpose:**
# To ensure that each property is represented only once in the dataset, preventing skewed analysis caused by duplicate entries.
#
# **Concepts Used:**
# - pandas.DataFrame.duplicated()
#
# - pandas.DataFrame.drop_duplicates()

# %%
# Count duplicates before removal
duplicates_count = df.duplicated().sum()
print("Number of duplicate rows:", duplicates_count)

# Remove duplicate rows
df = df.drop_duplicates()

# Verify removal
print("Shape after removing duplicates:", df.shape)
# Out:
# Number of duplicate rows: 0
# Shape after removing duplicates: (2930, 82)

# %% [markdown]
# **Expected Output:**
#
# The number of duplicate rows before removal.
#
# The new dataset shape with duplicates dropped.
#
# **Business Insight:**
#
# The dataset has no duplicate rows, and after checking, it retains its full shape of 2,930 records across 82 features. This means the data is unique, clean, and reliable for analysis without the risk of redundancy skewing insights.

# %% [markdown]
# ## Exercise 8: Group data – Average property price by city

# %% [markdown]
# **Purpose:**
# To analyze how property prices vary across different cities by calculating the average selling price per city.
#
# **Concepts Used:**
# - pandas.DataFrame.groupby()
# - Aggregation with .mean()

# %%
# Group data by city and calculate average SalePrice
avg_price_by_city = df.groupby("Neighborhood")["SalePrice"].mean().reset_index()

# Sort cities by average price (highest first)
avg_price_by_city = avg_price_by_city.sort_values(by="SalePrice", ascending=False)

print(avg_price_by_city)
# Out:
#    Neighborhood      SalePrice
# 18      NoRidge  330319.126761
# 25      StoneBr  324229.196078
# 19      NridgHt  322018.265060
# 10      GrnHill  280000.000000
# 27      Veenker  248314.583333
# 26       Timber  246599.541667
# 24      Somerst  229707.324176
# 4       ClearCr  208662.090909
# 6       Crawfor  207550.834951
# 5       CollgCr  201803.434457
# 0       Blmngtn  196661.678571
# 9        Greens  193531.250000
# 8       Gilbert  190646.575758
# 17       NWAmes  188406.908397
# 23      SawyerW  184070.184000
# 14      Mitchel  162226.631579
# 15        NAmes  145097.349887
# 1       Blueste  143590.000000
# 16      NPkVill  140710.869565
# 12      Landmrk  137000.000000
# 22       Sawyer  136751.152318
# 21        SWISU  135071.937500
# 7       Edwards  130843.381443
# 3       BrkSide  124756.250000
# 20      OldTown  123991.891213
# 2        BrDale  105608.333333
# 11       IDOTRR  103752.903226
# 13      MeadowV   95756.486486

# %% [markdown]
# **Expected Output:**
#
# A table showing each city(neighborhood) with its corresponding average property price, sorted from the highest to lowest.
#
# **Business Insight:**
#
# High-value neighborhoods (NoRidge, StoneBr, NridgHt) average over $320k, ideal for luxury housing.
# Mid-tier areas (Timber, Somerst, ClearCr) fall in the $200k–$250k range, reflecting stable middle-class markets.
# Lower-priced areas (OldTown, BrDale, MeadowV) average below $130k, offering opportunities for affordable housing and investments.
#
# **Business Use Case:**
#
# Developers can align project scale with neighborhood affordability.
#
# Agents should tailor marketing — luxury focus in NoRidge, affordability in OldTown.
#
# Investors may find strong ROI in low-price areas with renovation potential.

# %% [markdown]
# ## Exercise 9: Create new column → Price per Sqft = SalePrice / Sqft

# %% [markdown]
# Purpose:
#
# To understand property value efficiency by calculating the price per square foot. This helps compare properties of different sizes on a common scale.
#
# Concepts Used:
#
# Pandas column creation
#
# Arithmetic operations

# %%
# Create new column price_per_sqft
df["price_per_sqft"] = df["SalePrice"] / df["Gr Liv Area"]

# Display first 5 rows with new column
df[["SalePrice", "Gr Liv Area", "price_per_sqft"]].head()
# Out:
#    SalePrice  Gr Liv Area  price_per_sqft
# 0     215000         1656      129.830918
# 1     105000          896      117.187500
# 2     172000         1329      129.420617
# 3     244000         2110      115.639810
# 4     189900         1629      116.574586

# %% [markdown]
# **Expected Output:**
#
# A new column price_per_sqft will appear in the dataset. The preview will show SalePrice, Sqft, and the calculated price_per_sqft for the first 5 rows.
#
# **Business Insight:**
#
# - Homes in this sample range from about $116–$130 per sqft.
#
# - Even though total sale prices vary widely (from $105k to $244k), the price per sqft stays within a relatively narrow band.
#
# - This indicates that home size (Gr Liv Area) is a key driver of sale price — larger homes sell for more overall, but not necessarily at a higher per-sqft premium.
#
# **Use Case:**
#
# Buyers can benchmark fair pricing in the $115–$130/sqft range.
#
# Sellers/agents should emphasize unique features (location, quality, amenities) to push properties above the average per-sqft band.

# %% [markdown]
# ## Exercise 10: Convert column to datetime and extract month/year

# %% [markdown]
# **Purpose:**
#
# Understand the distribution of property listings over time. Helps answer: When do most listings occur?
#
# **Concepts Used:**
#
# Pandas datetime conversion (pd.to_datetime)
#
# Date attribute extraction (.dt.month, .dt.year)

# %%
# Combine Yr Sold and Mo Sold into a datetime (first day of each month)
df["SaleDate"] = pd.to_datetime(
    df["Yr Sold"].astype(str) + "-" + df["Mo Sold"].astype(str) + "-01"
)

df["Sale_Year"] = df["SaleDate"].dt.year
df["Sale_Month"] = df["SaleDate"].dt.month

listings_over_time = df.groupby(["Sale_Year", "Sale_Month"]).size().reset_index(name="Count")
print(listings_over_time.head())
# Out:
#    Sale_Year  Sale_Month  Count
# 0       2006           1     18
# 1       2006           2     24
# 2       2006           3     51
# 3       2006           4     48
# 4       2006           5     75

# %% [markdown]
# **Expected Output:**
#
# A DataFrame snippet showing three columns:
#
# Sale_Year
#
# Sale_Month
#
# Count
#
# **Business Insight:**
#
# - Listings rise sharply from winter into spring/summer, with May showing peak activity (75 in 2006).
#
# - This suggests that property sales are seasonal, with sellers preferring warmer months when buyer activity is higher.
#
# - Real estate agents should focus marketing campaigns and open houses in spring and summer for maximum visibility.
#
# - Developers and investors can time listings to align with these high-demand periods to secure better prices and faster sales.

# %% [markdown]
# ## Exercise 11: Find Top 5 Cities with Most Property Listings

# %% [markdown]
# **Purpose:**
#
# Identify the cities (actually neighborhoods, since our dataset uses that column instead of "city") with the highest number of property listings. This helps reveal areas with the most active real estate market.
#
# **Concepts Used:**
#
# pandas
#
# value_counts()
#
# Data filtering and ranking

# %%
# count listings per neighborhood and get top 5
top5_neighborhoods = df["Neighborhood"].value_counts().head(5)

top5_neighborhoods
# Out:
# Neighborhood
# NAmes      443
# CollgCr    267
# OldTown    239
# Edwards    194
# Somerst    182
# Name: count, dtype: int64

# %% [markdown]
# **Expected Output:**
#
# A Pandas Series with the top 5 neighborhoods and their corresponding listing counts.
#
# **Business Insight:**
#
# Most property listings are concentrated in a few key neighborhoods, with NAmes having the highest supply. This suggests these areas are more active markets, giving buyers more options and sellers higher competition.

# %% [markdown]
# ## Exercise 12: Pivot Table – Average Price by City vs Year

# %% [markdown]
# **Purpose:**
#
# Summarize the dataset to see how property prices vary across cities (neighborhoods in our dataset) over the years. This helps analyze price trends geographically and temporally.
#
# **Concepts Used:**
#
# pandas.pivot_table()
#
# Aggregation with mean
#
# Multi-dimensional analysis (rows = city, columns = year)

# %%
# create pivot table: average price by neighborhood vs year
pivot_avg_price = pd.pivot_table(
    df,
    values="SalePrice",
    index="Neighborhood",   # treating Neighborhood as City
    columns="Yr Sold",
    aggfunc="mean"
)

pivot_avg_price.head()
# Out:
# Yr Sold                2006           2007           2008           2009  \
# Neighborhood
# Blmngtn       214424.454545  194671.500000  190714.400000  177266.666667
# Blueste                 NaN  161950.000000  133750.000000  124250.000000
# BrDale        103444.444444  113740.000000   99507.142857  113750.000000
# BrkSide       115142.105263  125661.458333  122274.193548  133278.260870
# ClearCr       194430.000000  237111.111111  205175.636364  179666.666667
#
# Yr Sold                2010
# Neighborhood
# Blmngtn       176000.000000
# Blueste       173750.000000
# BrDale         96500.000000
# BrkSide       128563.636364
# ClearCr       220987.500000

# %% [markdown]
# **Expected Output**:
#
# A pivot table with neighborhoods (cities) as rows, years as columns, and average property prices as values.
#
# **Business Insight:**
#
# - Some neighborhoods (e.g., ClearCr) maintained higher average prices across years, showing resilience.
#
# - Others (e.g., Blmngtn, BrDale) showed a steady decline, possibly due to weaker demand or market conditions.
#
# - This breakdown helps identify stable vs volatile neighborhoods for long-term investment decisions.

# %% [markdown]
# ## Exercise 13: Correlation Matrix – Size, Bedrooms, Bathrooms, and Price

# %% [markdown]
# Purpose:
#
#  Identify how property characteristics (size, bedrooms, bathrooms) correlate with property prices.
#
#
# Concepts Used:
#
#  Pandas, Correlation (.corr()), Heatmap (Seaborn/Matplotlib).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# correlation matrix for selected numeric columns
df["Total_Bathrooms"] = df["Full Bath"] + 0.5*df["Half Bath"] + df["Bsmt Full Bath"] + 0.5*df["Bsmt Half Bath"]

corr_matrix = df[["Gr Liv Area", "Bedroom AbvGr", "Total_Bathrooms", "SalePrice"]].corr()


# visualize with heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix: Size, Bedrooms, Bathrooms, and Price")
plt.show()

# %% [markdown]
# **Expected Output:**
#
# A heatmap table showing correlation values between size, bedrooms, bathrooms, and price.
#
# For example:
#
# Size will likely have a strong positive correlation with Price.
#
# Bedrooms and Bathrooms will show moderate correlation with both Size and Price.
#
# **Business Insight:**
#
# The correlation matrix reveals key drivers of property value:
#
# - Gr Liv Area and Sale Price (0.71)
# → Strong positive correlation: Larger above-ground living spaces significantly boost sale price.
# Focus on building and marketing spacious homes.
#
# - Total Bathrooms and Sale Price (0.64)
# → High correlation: More bathrooms add substantial value.
# Adding or upgrading bathrooms can increase return on investment.
#
# - Bedrooms Above Ground and Sale Price (0.14)
# → Weak correlation: Additional bedrooms have minimal impact on price.
# Don’t prioritize bedroom count over space and functionality.

# %% [markdown]
# ## Exercise 14: Visualization – Top 10 Cities by Total Sales (Bar Chart)

# %% [markdown]
# Purpose:
#
# Which cities contribute the most to overall property sales? This helps identify high-value real estate markets.
#
# Concepts Used:
#
# Pandas (groupby, nlargest)
#
# Matplotlib (bar)

# %%
import matplotlib.pyplot as plt

# Group data by neighborhood and calculate total sales
city_sales = df.groupby("Neighborhood")["SalePrice"].sum().nlargest(10)

# Plot bar chart
plt.figure(figsize=(10,6))
city_sales.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Top 10 Cities by Total Sales")
plt.xlabel("Neighborhood")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Expected Output:**
#
# A bar chart with the top 10 neighborhoods on the x-axis and their total property sales on the y-axis. The bars will show which neighborhoods dominate in sales volume.
#
# **Business Insight:**
#
# - NAmes has the highest total sales, making it the most lucrative neighborhood.
#
# - CollgCr and NridgHt follow closely with strong sales volumes.
#
# - Somerset and Gilbert are mid-high performers, indicating healthy demand.
#
# - OldTown, Edwards, NWAmes, NoRidge, and SawyerW show moderate but stable sales.

# %% [markdown]
# ## Exercise 15: Complex EDA – Yearly House Price Trend (Line Chart)

# %% [markdown]
# **Purpose:**
#
# To analyze how house prices have changed over the years. This reveals market trends (growth, decline, or stability) in real estate prices.
#
# **Concepts Used:**
#
# Pandas (groupby, mean)
#
# Matplotlib (plot)

# %%
# Calculate average price per year
yearly_trend = df.groupby("Yr Sold")["SalePrice"].mean()

# Plot line chart
plt.figure(figsize=(10,6))
plt.plot(yearly_trend.index, yearly_trend.values, marker="o", linestyle="-", color="green")
plt.title("Yearly House Price Trend")
plt.xlabel("Year")
plt.ylabel("Average Price")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# **Expected Output:**
#
# A line chart showing average house price per year. Each point represents the mean property price in that year.
#
# **Business Insight:**
#
# - Peak average house prices occurred in 2007, followed by a sharp decline in 2008.
#
# - A slight recovery happened in 2009, but prices dropped again to the lowest point in 2010.
#
# - Overall, the trend from 2007 to 2010 shows a downward trajectory, likely reflecting the impact of the global financial crisis.

# %% [markdown]
# ## Exercise 16: House Size Distribution (Histogram)

# %% [markdown]
# **Purpose:**
#
#  Understand which property sizes are most frequent, helping real estate investors and builders target the most in-demand size ranges.
#
# **Concepts Used:**
#
#  Pandas, Matplotlib, Histogram.

# %%
# Plot histogram for house sizes
plt.figure(figsize=(8,5))
plt.hist(df["Gr Liv Area"], bins=30, color="skyblue", edgecolor="black")

plt.title("House Size Distribution", fontsize=14)
plt.xlabel("Size (sqft)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Expected Output:**
#
# A histogram showing how frequently different house sizes appear in the dataset, with peaks indicating the most common ranges (e.g., small apartments vs large villas).
#
# **Business Insight:**
#
# - Most houses fall within the 1,000 to 2,000 sqft range, with a peak around 1,200–1,500 sqft.
#
# - The distribution is right-skewed, meaning larger homes (above 3,000 sqft) are rare.
#
# - Very few properties exceed 4,000 sqft, indicating limited demand or supply for large luxury homes.

# %% [markdown]
# ## Exercise 17: House Prices by Region (Box Plot)

# %% [markdown]
# **Purpose:**
#
#  Visualize how house prices vary across regions, highlight outliers, and spot areas with high variability in prices.
#
# **Concepts Used:**
#
#  Pandas, Matplotlib, Seaborn (boxplot).

# %%
# Boxplot of house prices by region
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x="Neighborhood", y="SalePrice", palette="Set2")

plt.title("House Prices by Neighborhood", fontsize=14)
plt.xlabel("Neighborhood")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Fame\AppData\Local\Temp\ipykernel_12392\4123802036.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Neighborhood", y="SalePrice", palette="Set2")

# %% [markdown]
# **Expected Output:**
#
# A box plot with one box per region, showing median house price, interquartile range, and outliers (dots).
#
# **Business Insight:**
#
# - Highest-priced neighborhoods include **NridgHt, StoneBr, and NoRidge,** with many homes priced well above $400,000.
#
# - Mid-priced neighborhoods like Gilbert, Veenker, and Crawfor show consistent pricing between $200,000–$300,000.
#
# - Lower-priced areas such as *BrDale, IDOTRR, and MeadowV have prices mostly under $150,000.*
#
# - Wide price variation is seen in areas like NAmes and Edwards, indicating a mix of property types and conditions.

# %% [markdown]
# ## Exercise 18: Building Type Breakdown (Pie Chart)

# %% [markdown]
# **Purpose:**
#
# Understand the proportion of each building type in the dataset.
#
# **Concepts Used:**
#
# Pandas, Matplotlib.

# %%
# Using BldgType (property type like 1-family, duplex, townhouse)
property_counts = df["Bldg Type"].value_counts()

# Pie chart
plt.figure(figsize=(10,10))
plt.pie(property_counts, labels=property_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Distribution of Property Types", fontsize=14)
plt.show()

# %% [markdown]
# **Expected Output:**
#
# A pie chart showing the proportion of each buildig type (e.g. 1-family, duplex, townhouse).
#
# **Business Insight:**
#
# - **Single-family homes** dominate the market, making up **82.8% **of all properties.
#
# - **Townhouses (TwnhsE) account for 8.0%**, the largest among alternative property types.
#
# - Duplexes, Townhouses, and 2-family conversions (2fmCon) together represent a *small share (under 10% combined).*

# %% [markdown]
# ## Exercise 19: Trend Analysis Over Time (Line Plot)

# %% [markdown]
# **Purpose:**
#
#  Identify long-term price trends and seasonal variations in the housing market.
#
# **Concepts Used:**
#
#  Pandas (groupby, datetime), Matplotlib.

# %%
# Group by Month Sold and calculate average price
monthly_trend = df.groupby("Mo Sold")["SalePrice"].mean()

# Line plot
plt.figure(figsize=(10,5))
plt.plot(monthly_trend.index, monthly_trend.values, marker='o', linewidth=2)
plt.title("Average Housing Prices by Month", fontsize=14)
plt.xlabel("Month Sold", fontsize=12)
plt.ylabel("Average Price", fontsize=12)
plt.xticks(range(1, 13))  # ensure months 1–12 appear
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %% [markdown]
# **Expected Output:**
#
# A line chart with time (x-axis) vs average monthly price (y-axis).
#
# Clear upward/downward trends and possible seasonal fluctuations.
#
# **Business Insight:**
#
# - Average housing prices are **highest in January** and again peak in September and November.
#
# - Prices dip to their l**owest in April**, with a gradual recovery from May through September.
#
# - he trend suggests *seasonal fluctuations* in housing prices throughout the year.

# %% [markdown]
# ## Exercise 20 – Heatmap of Average House Prices by Sale Year and Month

# %% [markdown]
# **Purpose:**
#
# To analyze seasonal and yearly patterns in house prices, identifying which months and years tend to have higher or lower sale prices.
#
# **Concepts Used:**
#
# - Pandas groupby and unstack for pivoting data
#
# - Matplotlib for visualization
#
# - Seaborn heatmap for clear comparison

# %%
price_heatmap = df.groupby(['Yr Sold','Mo Sold'])['SalePrice'].mean().unstack()

plt.figure(figsize=(12,6))
sns.heatmap(price_heatmap, annot=True, fmt=".0f",cmap="YlGnBu")
plt.title("Average Price Heatmap (Year vs Month)")
plt.show()

# %% [markdown]
# **Expected Output:**
#
# A heatmap where rows represent years sold and columns represent months sold. Each cell shows the average house price for that specific year-month combination. Colors indicate relative price levels (lighter = higher prices, darker = lower).
#
# **Business Insights:**
#
# - House prices show clear seasonal patterns, with *August and November* being the most profitable months for selling.
#
# - Prices **peaked between 2006 and 2009**, then declined slightly in 2010.
#
# - Buyers may find better deals in spring and early summer months like April, May, and July.
#
# - Sellers should target *high-price months* to maximize returns, while buyers can focus on lower-price months for savings.
